# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt # pyplot is used to plot 2D data
from pywaffle import Waffle
from wordcloud import WordCloud, STOPWORDS

# %%
# To check if matplotlib is interactive or not. True indicates interactive.
print('matplotlib.is_interactive():',matplotlib.is_interactive())
# Out:
# matplotlib.is_interactive(): True

# %%
# To set the number of rows to show while printing a dataframe,here it is 6.
pd.set_option('max_rows',6)

# %%
# Te output of matplotlib is printed inline - right below the code cell
# %matplotlib inline

# %%
# matplotlib inline is just one type of backend, the other backend available are as follows:
# %matplotlib -l
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %% [markdown]
# ## Creating a Sample DataFrame

# %%
q=np.random.randint(1,20,60).reshape(30,2)
p=np.random.randint(500,1000,60).reshape(30,2)
data=np.hstack((q,p))
df=pd.DataFrame(data,columns=['Quantity_A','Quantity_B','Price_A','Price_B'])
df['Revenue_A']=df['Quantity_A']*df['Price_A']
df['Revenue_B']=df['Quantity_B']*df['Price_B']
df.index.names=['Days']
print('As you can see, now the dataframe is showing 6 rows, exactly what we has set above')
df
# Out:
# As you can see, now the dataframe is showing 6 rows, exactly what we has set above
#       Quantity_A  Quantity_B  Price_A  Price_B  Revenue_A  Revenue_B
# Days
# 0              4           2      850      949       3400       1898
# 1              8          18      997      695       7976      12510
# 2              3           8      608      921       1824       7368
# ...          ...         ...      ...      ...        ...        ...
# 27            18           7      816      620      14688       4340
# 28            13          18      906      755      11778      13590
# 29            14          14      843      967      11802      13538
#
# [30 rows x 6 columns]

# %% [markdown]
# ## Plotting the DataFrame

# %%
# Pandas Library provides ibuilt plot function. 
# figsize can be passed as an argument that takes a tuple - (width, height)
df.plot(figsize=(11,6));

# %% [markdown]
# ## DataFrame columns can be plot separately as well

# %%
# subplots=True, plots each column of the dataframe separately. 
# We use semicolon in the end of the plot statement to avoid printing object names of the plot.
df.plot(subplots=True,figsize=(11,10));

# %% [markdown]
# ## Rearranging subplots: layout parameter

# %%
# layout parameter (rows,columns)  helps in re-arranging the subplots
# For each of these subplots, the x-axis (days) is shared
df.plot(subplots=True,layout=(3,2),figsize=(13,10));  
plt.tight_layout()

# %% [markdown]
# ## To plot only selected columns of the dataframe

# %%
# in order to plot specific columns, example: Revenue_A & Revenue_B
df[['Revenue_A','Revenue_B']].plot(figsize=(10,4));
plt.tight_layout()

# %% [markdown]
# ## Creating a DataFrame with random values

# %%
a=np.random.rand(500)
data=np.reshape(a,[100,5])
df=pd.DataFrame(data,columns=['A','B','C','D','E'])
df
# Out:
#            A         B         C         D         E
# 0   0.348437  0.393304  0.777667  0.947195  0.041650
# 1   0.455120  0.688211  0.106761  0.454110  0.320758
# 2   0.173932  0.140419  0.786160  0.208532  0.522774
# ..       ...       ...       ...       ...       ...
# 97  0.579281  0.352939  0.392679  0.351425  0.997108
# 98  0.030704  0.575142  0.435334  0.443015  0.382845
# 99  0.694906  0.625250  0.882839  0.886528  0.246035
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Plotting Histogram of DataFrame

# %%
# inbuilt dataframe histogram
# kind depicts the type of graph, width defines the size of each bar,alpha represents the transparency 
# bins defines the number of bars along the dataset
# Note here that both the columns (Series) are plotted on the same graph.
# In order to prevent this, we need to define axes object 

df['A'].plot(kind='hist',width=0.06,bins=10,title='Histogram Comparision',alpha=0.8,figsize=(10,6));
df['B'].hist(width=0.015,bins=10,color='red',figsize=(11,6));

# %% [markdown]
# ## Scatter Plot

# %%
# To give color representation, parameter c needs to be defined with the series of the dataframe
df.plot.scatter(x='A',y='B',c='C',cmap='plasma',\
                title='Scatter Plot with Color (c) representing third dimension',figsize=(10,6));

# %%
# To change the size of each element of the plot wrt to series, 
        # parameter s needs to be initialized with that parameter
df.plot.scatter(x='A',y='B',s=df['C']*100,\
                title='Scatter Plot with Size (s) representing third dimension',figsize=(10,6));

# %% [markdown]
# ## Creating DataFrame with random values

# %%
a=np.random.randn(500)
data1=np.reshape(a,[250,2])
df1=pd.DataFrame(data1,columns=['A','B'])
df1
# Out:
#             A         B
# 0    0.949215 -1.902049
# 1   -0.928089  0.288690
# 2   -1.441391  0.227932
# ..        ...       ...
# 247 -0.652913  0.795214
# 248 -1.605113  0.742695
# 249 -0.071136  0.215542
#
# [250 rows x 2 columns]

# %% [markdown]
# ## Hexagon Plot

# %%
df1.plot.hexbin(x='A',y='B',gridsize=15,cmap='coolwarm',title='Hexagon Plot',figsize=(11,6),alpha=0.7);

# %% [markdown]
# ## Kernel Density Estimate Plot

# %%
df1.plot.kde(title='Density graph',figsize=(11,6));

# %% [markdown]
# ## Creating DataFrame with random values

# %%
a=np.random.randint(1,10,25)
data=np.reshape(a,[5,5])
df=pd.DataFrame(data,columns=['P','Q','R','S','T'])
df
# Out:
#    P  Q  R  S  T
# 0  6  7  5  6  9
# 1  1  9  5  3  8
# 2  2  1  3  5  2
# 3  7  7  9  9  7
# 4  9  5  1  5  8

# %% [markdown]
# ## Area Graph

# %%
df.plot.area(alpha=0.5,title='Stacked Area Graph',figsize=(11,6));

# %%
# To produce an unstacked plot, pass stacked=False
df.plot.area(alpha=0.5,title='Un-stacked Area Graph',figsize=(11,6),stacked=False);

# %% [markdown]
# ## Plotting Stacked Bars and Bar Graphs

# %%
df.index=['A','B','C','D','E']
print(df)
df.plot(kind='bar',title='Bar Graph',figsize=(11,6),alpha=0.7);
df.plot(kind='bar',stacked=True,title='Vertical Stacked Bar Graph',figsize=(11,6),alpha=0.7);
# Out:
#    P  Q  R  S  T
# A  6  7  5  6  9
# B  1  9  5  3  8
# C  2  1  3  5  2
# D  7  7  9  9  7
# E  9  5  1  5  8

# %% [markdown]
# ## Box Plot

# %%
df.plot.box(title='Box Plot',figsize=(11,6));

# %% [markdown]
# ## Pie Chart

# %%
sales=df.sum()
print(sales)
sales.plot.pie(figsize=(11,6),title='Sales of each category');
# Out:
# P    25
# Q    29
# R    23
# S    28
# T    34
# dtype: int64

# %% [markdown]
# ## Vertical and Horizontal Bar Graph

# %%
fig,axes=plt.subplots(1,2,figsize=(12,5))

x = [5,8,10] 
y = [12,16,6]  
axes[0].bar(x, y, align = 'center')
axes[1].barh(x, y, align = 'center')

x2 = [6,9,11] 
y2 = [6,15,7] 
axes[0].bar(x2, y2, color = 'g', align = 'center',alpha=0.6) # vertical
axes[1].barh(x2, y2, color = 'g', align = 'center',alpha=0.6) # horizontal

axes[0].set_title('Vertical Bar graph')
axes[0].set_ylabel('Y') 
axes[0].set_xlabel('X')

axes[1].set_title('Horizontal Bar graph') 
axes[1].set_ylabel('X') 
axes[1].set_xlabel('Y')

plt.show()

# %%
x=['A','B','C']
y=[6,8,4]

plt.figure(figsize=(11,6))
plt.title("Allocation")
wedges,texts,autotexts=plt.pie(y,labels=x,explode=[0,0,0.05],autopct='%.2f%%',pctdistance=0.5,labeldistance=0.85)
print('Wedges:',wedges)
print('\nTexts:',texts)
print('\nAutotexts:',autotexts)

# formatting individual components
wedges[2].set(facecolor='pink',edgecolor='brown')
texts[1].set(weight='bold',size=14)
autotexts[1].set(weight='bold',size=14)
# Out:
# Wedges: [<matplotlib.patches.Wedge object at 0x7f4584997cc0>, <matplotlib.patches.Wedge object at 0x7f45849a3400>, <matplotlib.patches.Wedge object at 0x7f45849a3ac8>]
#
# Texts: [Text(0.42499997702644066, 0.736121606480563, 'A'), Text(-0.7987387064977634, -0.29071717999161967, 'B'), Text(0.6894400499618789, -0.5785087877539649, 'C')]
#
# Autotexts: [Text(0.24999998648614158, 0.4330127096944488, '33.33%'), Text(-0.4698462979398608, -0.17101010587742332, '44.44%'), Text(0.4213244749767038, -0.35353314807186736, '22.22%')]

# %% [markdown]
# ## HeatMap

# %% [markdown]
# ### Reading the iris dataset

# %%
iris_data = pd.read_csv('iris_data.csv')

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# get correlation matrix
corr = iris_data.corr()
fig, ax = plt.subplots()
# create heatmap
im = ax.imshow(corr.values)

# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
# Out:
# [None, None, None, None, None, None, None, None]

# %% [markdown]
# ## Faceting

# %%
from pandas.plotting import scatter_matrix

fig, ax = plt.subplots(figsize=(12,12))
scatter_matrix(iris_data, alpha=1, ax=ax);
# Out:
# /home/deepshikha/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Connected Scatter Plot

# %%
# Creating a DataFrame with random values 
df=pd.DataFrame({'x': range(1,10), 'y': np.random.randn(9)*80+range(1,10) })
 
# plot
plt.figure(figsize=(11,6))
plt.plot( 'x', 'y', data=df, linestyle='-', marker='o')
plt.show()
# Out:
# /home/deepshikha/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.

# %% [markdown]
# ## Line Plot with several lines

# %%
df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
 
# multiple line plot
plt.figure(figsize=(11,6))
plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend()
# Out:
# /home/deepshikha/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: Second argument 'y1' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   """
# /home/deepshikha/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Second argument 'y2' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#
# /home/deepshikha/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: Second argument 'y3' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   import sys

# %% [markdown]
# ## Highlighting a single line in Line Plot

# %%
# Make a data frame
df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21), 'y4': np.random.randn(10)+range(6,16), 'y5': np.random.randn(10)+range(4,14)+(0,0,0,0,0,0,0,-3,-8,-6), 'y6': np.random.randn(10)+range(2,12), 'y7': np.random.randn(10)+range(5,15), 'y8': np.random.randn(10)+range(4,14) })
 
#plt.style.use('fivethirtyeight')
plt.style.use('seaborn-darkgrid')
my_dpi=96
plt.figure(figsize=(480/my_dpi, 480/my_dpi), dpi=my_dpi)
 
# multiple line plot
for column in df.drop('x', axis=1):
   plt.plot(df['x'], df[column], marker='', color='grey', linewidth=1, alpha=0.4)
 
# Now re do the interesting curve, but biger with distinct color
plt.plot(df['x'], df['y5'], marker='', color='orange', linewidth=4, alpha=0.7)
 
# Change xlim
plt.xlim(0,12)
 
# Let's annotate the plot
num=0
for i in df.values[9][1:]:
   num+=1
   name=list(df)[num]
   if name != 'y5':
      plt.text(10.2, i, name, horizontalalignment='left', size='small', color='grey')
 
# And add a special annotation for the group we are interested in
plt.text(10.2, df.y5.tail(1), 'Mr Orange', horizontalalignment='left', size='small', color='orange')
 
# Add titles
plt.title("Evolution of Mr Orange vs other students", loc='left', fontsize=12, fontweight=0, color='orange')
plt.xlabel("Time")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# ## Bubble Plots

# %%
x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)
 
# use the scatter function
plt.figure(figsize=(11,6))
plt.scatter(x, y, s=z*1000, alpha=0.5)
plt.show()

# %% [markdown]
# ## Waffle Charts

# %%
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
fig = plt.figure(
    figsize=(11,6),
    FigureClass=Waffle, 
    rows=5, 
    values=data, 
    colors=("#983D3D", "#232066", "#DCB732"),
    title={'label': 'Vote Percentage in 2016 US Presidential Election', 'loc': 'left'},
    labels=["{0} ({1}%)".format(k, v) for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.4), 'ncol': len(data), 'framealpha': 0}
)
fig.gca().set_facecolor('#EEEEEE')
fig.set_facecolor('#EEEEEE')
plt.show()
# Out:
# <Waffle size 792x432 with 1 Axes>

# %% [markdown]
# ## Word Clouds

# %%
alice_novel = "Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."

# %%
alice_wc = WordCloud(
    background_color='white',
    max_words=2000,
#     stopwords=stopwords
)
 
# generate the word cloud
alice_wc.generate(alice_novel)
 
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height
 
# display the cloud
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# There are two types of Plotting styles:
# 1. Scripting Layes - (procedural method) –  using matplotlib.pyplot as ‘plot’
# 2. Artist layer (Object oriented method) – using an Axes instance from Matplotlib (preferred)
#
# In the second way, you can use an Axes instance of your current plot and store it in a variable. Example of this is given below

# %%
# Making a dummy DataFrame
dict_dummy = {'A':[1, 3, 6, 10, 3], 'B':[3, 7, 70, 60, 4], 'C':[7, 67, 36, 10, 7]}

dummy_df = pd.DataFrame.from_dict(dict_dummy, orient='index').T

# %%
ax = dummy_df.plot(kind='area', alpha=0.35, figsize=(20, 10))
 
ax.set_title('Graph - 1')
ax.set_ylabel('Random Categories')
ax.set_xlabel('Random Numbers')
# Out:
# Text(0.5, 0, 'Random Numbers')
